# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %%
print("text data:", text[:100])
# Out:
# text data:  anarchism originated as a term of abuse first used against early working class radicals including t

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
print("Unique words (before preprocessing): {}".format(len(set(text.split()))))
# Out:
# Unique words (before preprocessing): 253854

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %%
import matplotlib.pyplot as plt
from collections import Counter

word_counts = Counter(words)
labels, values = zip(*word_counts.most_common())
x, y = zip(*list(enumerate(values[:100])))

plt.plot(x, y)
plt.show()

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. 
    현재 idx 앞, 뒤에서 r개씩 word를 골라 반환한다(r은 랜덤하게 정해짐).
    위 설명에서 distant words에 less weight를 주는 것을 이렇게 구현할 수 있음.'''
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    # 리스트에 중복 단어가 있을 수 있으므로 set으로 처리한다. 
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches. 뒤에 나머지는 잘라낸다.
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            # batch_size가 정해져있기 때문에 batch는 고정 크기이지만 
            # get_target이 반환하는 label 리스트의 크기가 랜덤이기 때문에
            # get_batches에서 반환하는 x, y의 크기도 매번 바뀔 것이다. 
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(dtype=tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(dtype=tf.int32, shape=[None, 1], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1.0, 1.0)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(
        softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.5896 0.5125 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5703 0.5587 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4588 0.5396 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5078 0.6519 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4432 0.5768 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5115 0.5309 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.4948 0.5512 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5055 0.5359 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4655 0.5421 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4084 0.5701 sec/batch
# Nearest to been: wyatt, profile, manny, whitehead, persisting, subcontinent, radiochemistry, usury,
# Nearest to from: moscow, accompaniment, daltrey, norouz, pino, vitrification, rak, loaves,
# Nearest to about: suzaku, berlusconi, purse, herod, softpanorama, rvinen, mbit, hell,
# Nearest to at: lindh, regimental, fanlisting, insurance, product, coupe, televison, catastrophic,
# Nearest to people: sunken, isomer, majestic, construed, redeeming, liam, mca, freed,
# Nearest to up: haldeman, recessive, screw, breaker, mango, journalist, ancona, inductees,
# Nearest to their: stub, the, rabble, usefully, aspartic, daydream, thrives, auf,
# Nearest to into: repentant, underemployed, succ, puppets, pollute, difranco, harmonium, rolls,
# Nearest to hit: listened, amarantine, diazonium, fg, dispenses, zug, kindia, hecatonchires,
# Nearest to older: sari, charenton, unsustainable, stomping, cramps, horizontal, assessors, harmonicist,
# Nearest to scale: jewellery, metadata, catfish, fatigue, reproductive, qimei, maulana, bitrate,
# Nearest to instance: neptunian, canisters, roussillon, equipping, hydrogenation, milieu, rendition, sterilizing,
# Nearest to joseph: stomp, gassed, johan, robins, joannes, disaster, predate, statesman,
# Nearest to centre: ambiente, aircrew, zealots, lorien, infirmary, knapsack, kerenyi, theorize,
# Nearest to engineering: pnc, alamein, khedive, clothing, shinai, duvall, labyrinths, nationalised,
# Nearest to consists: nation, backward, tectonics, recreation, roly, bangkok, czarist, cognitively,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4821 0.5506 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3334 0.5305 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3276 0.5268 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2275 0.5316 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1798 0.4957 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1495 0.5003 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0901 0.5229 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0892 0.5341 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0130 0.4952 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9970 0.5079 sec/batch
# Nearest to been: profile, wyatt, radiochemistry, subcontinent, provides, reducing, persisting, hated,
# Nearest to from: moscow, accompaniment, then, pino, rak, vitrification, phase, sum,
# Nearest to about: herod, television, suzaku, hell, purse, authorities, lies, virtually,
# Nearest to at: product, total, insurance, disappearing, lindh, catastrophic, lacking, regimental,
# Nearest to people: sunken, construed, smuggler, isomer, declared, majestic, terry, friends,
# Nearest to up: haldeman, journalist, male, screw, breaker, mango, barbary, depending,
# Nearest to their: stub, attempted, the, usefully, rabble, aspartic, cfm, excessive,
# Nearest to into: rolls, pollute, repentant, underemployed, docetism, puppets, danse, brothers,
# Nearest to hit: amarantine, followed, listened, dispenses, entities, enhances, fg, zug,
# Nearest to older: sari, horizontal, charenton, reconstructing, breve, recording, mountain, severity,
# Nearest to scale: jewellery, fatigue, metadata, reproductive, new, bitrate, discussion, wanting,
# Nearest to instance: neptunian, canisters, technological, buddhism, roussillon, rendition, beginning, kontor,
# Nearest to joseph: stomp, designers, johan, gassed, writing, robins, disaster, example,
# Nearest to centre: lorien, ambiente, aircrew, zealots, course, gains, kerenyi, infirmary,
# Nearest to engineering: pnc, clothing, khedive, alamein, shinai, placed, advancing, duvall,
# Nearest to consists: nation, backward, tectonics, recreation, lexicon, established, roly, pound,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9473 0.5284 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9113 0.5466 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8843 0.5236 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8664 0.4841 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8636 0.4564 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8335 29.7951 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8285 0.7163 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7557 0.5464 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7700 0.5196 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7812 0.4720 sec/batch
# Nearest to been: profile, wyatt, reducing, subcontinent, begotten, radiochemistry, whitehead, persisting,
# Nearest to from: moscow, accompaniment, posted, sum, norouz, withdrawing, vitrification, then,
# Nearest to about: suzaku, herod, hell, purse, kg, favors, television, genealogy,
# Nearest to at: insurance, disappearing, regimental, product, total, catastrophic, lindh, web,
# Nearest to people: sunken, freed, construed, friends, isomer, majestic, smuggler, denying,
# Nearest to up: haldeman, journalist, breaker, screw, barbary, mango, dividing, inductees,
# Nearest to their: stub, usefully, rabble, attempted, hanover, cfm, excessive, the,
# Nearest to into: initiative, puppets, repentant, underemployed, pollute, mecca, rolls, succ,
# Nearest to hit: amarantine, listened, followed, entities, fg, enhances, preparation, dispenses,
# Nearest to older: sari, horizontal, charenton, reconstructing, recording, severity, unsustainable, hyland,
# Nearest to scale: jewellery, reproductive, fatigue, metadata, fertility, grandmasters, new, regions,
# Nearest to instance: neptunian, rendition, canisters, sterilizing, buddhism, technological, roussillon, milieu,
# Nearest to joseph: stomp, statesman, designers, johan, disaster, writing, author, gassed,
# Nearest to centre: lorien, aircrew, rigorously, ambiente, lakes, gains, course, parsing,
# Nearest to engineering: pnc, clothing, khedive, alamein, shinai, containers, pharmaceuticals, ambassador,
# Nearest to consists: nation, backward, recreation, lexicon, tectonics, scouting, czarist, hoop,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7830 0.4712 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7755 0.4662 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7152 53.5908 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7252 0.6052 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7544 0.5577 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7146 0.5616 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7023 0.5477 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7247 0.5469 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7043 0.6226 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6597 0.5670 sec/batch
# Nearest to been: profile, subcontinent, wyatt, whitehead, manny, reducing, begotten, persisting,
# Nearest to from: moscow, accompaniment, norouz, withdrawing, buddha, posted, vogue, loaves,
# Nearest to about: suzaku, herod, purse, hell, genealogy, softpanorama, berlusconi, authorities,
# Nearest to at: insurance, disappearing, lindh, regimental, catastrophic, total, mc, product,
# Nearest to people: sunken, majestic, freed, construed, smuggler, liam, friends, isomer,
# Nearest to up: haldeman, journalist, breaker, screw, mango, inductees, recessive, pornography,
# Nearest to their: stub, rabble, hanover, usefully, cfm, thrives, villains, excessive,
# Nearest to into: puppets, underemployed, initiative, repentant, pollute, mecca, succ, harmonium,
# Nearest to hit: amarantine, listened, fg, presupposition, enhances, followed, annul, preparation,
# Nearest to older: sari, reconstructing, charenton, recording, horizontal, hyland, severity, stomping,
# Nearest to scale: jewellery, reproductive, fatigue, metadata, bitrate, whites, grandmasters, maulana,
# Nearest to instance: neptunian, rendition, canisters, buddhism, milieu, sterilizing, technological, roussillon,
# Nearest to joseph: statesman, stomp, author, johan, svenska, predate, reads, disaster,
# Nearest to centre: rigorously, lorien, aircrew, ambiente, infirmary, lakes, maximilien, theorize,
# Nearest to engineering: pnc, clothing, khedive, alamein, internetworking, nationalised, duvall, containers,
# Nearest to consists: nation, scouting, backward, lexicon, recreation, tectonics, hoop, haldane,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6556 0.5889 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.7014 0.5716 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6148 0.5420 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6348 0.5369 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6457 0.5452 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6300 0.5891 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6184 0.4117 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5258 0.5502 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5337 0.6033 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5033 0.5587 sec/batch
# Nearest to been: profile, manny, reducing, usury, begotten, subcontinent, whitehead, advise,
# Nearest to from: moscow, accompaniment, norouz, buddha, daltrey, loaves, withdrawing, addiction,
# Nearest to about: suzaku, herod, purse, hell, genealogy, spanned, copper, authorities,
# Nearest to at: disappearing, insurance, lindh, regimental, mc, total, catastrophic, boondocks,
# Nearest to people: sunken, majestic, freed, smuggler, construed, friends, redeeming, declared,
# Nearest to up: haldeman, breaker, mango, ancona, screw, inductees, spock, journalist,
# Nearest to their: stub, rabble, hanover, usefully, cfm, excessive, skits, villains,
# Nearest to into: underemployed, succ, repentant, initiative, puppets, mecca, pollute, harmonium,
# Nearest to hit: amarantine, annul, microcontroller, presupposition, listened, followed, fg, enhances,
# Nearest to older: sari, charenton, recording, reconstructing, horizontal, breve, hyland, assessors,
# Nearest to scale: jewellery, reproductive, fatigue, bitrate, metadata, catfish, whites, if,
# Nearest to instance: neptunian, rendition, canisters, sterilizing, technological, subtle, milieu, ieee,
# Nearest to joseph: statesman, author, johan, d, stomp, svenska, valens, predate,
# Nearest to centre: rigorously, aircrew, lorien, mircea, lakes, gains, ambiente, ambon,
# Nearest to engineering: pnc, clothing, khedive, alamein, containers, fermentation, internetworking, pharmaceuticals,
# Nearest to consists: nation, scouting, recreation, backward, haldane, hoop, tectonics, lexicon,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5141 0.5597 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4670 0.5796 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4898 0.5543 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5007 0.5550 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4917 0.5478 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4615 0.5535 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4523 0.5568 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3844 0.6249 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4154 0.5756 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4112 0.5676 sec/batch
# Nearest to been: manny, profile, persisting, usury, encroachments, reducing, begotten, palaeolithic,
# Nearest to from: moscow, norouz, loaves, accompaniment, buddha, daltrey, withdrawing, addiction,
# Nearest to about: suzaku, genealogy, purse, herod, copper, lies, limnic, newington,
# Nearest to at: disappearing, insurance, regimental, lindh, catastrophic, total, aeons, mc,
# Nearest to people: sunken, majestic, declared, aryana, freed, construed, redeeming, isaf,
# Nearest to up: haldeman, breaker, spock, mango, ancona, regrouped, screw, celluloid,
# Nearest to their: rabble, stub, hanover, usefully, excessive, skits, cfm, halford,
# Nearest to into: underemployed, succ, mecca, humidity, initiative, repentant, pollute, puppets,
# Nearest to hit: microcontroller, amarantine, annul, followed, listened, fg, enhances, jeane,
# Nearest to older: sari, recording, charenton, reconstructing, breve, assessors, horizontal, hyland,
# Nearest to scale: jewellery, reproductive, fatigue, metadata, bitrate, straightforward, catfish, grandmasters,
# Nearest to instance: neptunian, canisters, rendition, subtle, mistakes, ieee, milieu, sterilizing,
# Nearest to joseph: statesman, johan, author, svenska, d, stomp, valens, woodward,
# Nearest to centre: aircrew, rigorously, ambiente, lakes, mircea, ambon, gains, course,
# Nearest to engineering: pnc, clothing, containers, pharmaceuticals, khedive, fermentation, internetworking, nationalised,
# Nearest to consists: nation, scouting, recreation, haldane, slurry, hoop, backward, tectonics,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4175 0.5749 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4265 0.5727 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4301 0.5779 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4004 0.6154 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4139 0.5584 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4514 0.5798 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3888 0.5875 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3617 0.6158 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3992 0.5517 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3819 0.6381 sec/batch
# Nearest to been: profile, usury, manny, palaeolithic, encroachments, radiochemistry, contenders, persisting,
# Nearest to from: norouz, moscow, loaves, accompaniment, daltrey, buddha, tread, withdrawing,
# Nearest to about: suzaku, genealogy, copper, herod, spanned, purse, marks, limnic,
# Nearest to at: disappearing, insurance, boondocks, regimental, philharmonic, lindh, uniformitarianism, total,
# Nearest to people: sunken, aryana, declared, majestic, freed, redeeming, heisei, construed,
# Nearest to up: breaker, haldeman, mango, spock, screw, celluloid, journalist, depending,
# Nearest to their: stub, rabble, usefully, hanover, excessive, who, skits, cfm,
# Nearest to into: succ, underemployed, initiative, humidity, repentant, mecca, pollute, puppets,
# Nearest to hit: microcontroller, followed, annul, amarantine, listened, fg, enhances, episode,
# Nearest to older: recording, reconstructing, charenton, sari, female, assessors, animators, breve,
# Nearest to scale: reproductive, jewellery, fatigue, bitrate, metadata, straightforward, catfish, manganese,
# Nearest to instance: neptunian, canisters, subtle, rendition, sterilizing, mankind, ieee, technological,
# Nearest to joseph: statesman, johan, author, svenska, d, johann, valens, woodward,
# Nearest to centre: aircrew, lakes, ambiente, rigorously, ambon, mircea, gains, knapsack,
# Nearest to engineering: pnc, clothing, containers, khedive, pharmaceuticals, fermentation, internetworking, parkman,
# Nearest to consists: nation, scouting, slurry, haldane, hoop, recreation, tectonics, backward,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3651 0.6085 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3706 0.6856 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3566 0.6710 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3486 0.6411 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3655 0.6538 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3695 0.6544 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3817 0.6761 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3732 0.6394 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3349 0.6316 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3126 0.6209 sec/batch
# Nearest to been: profile, usury, palaeolithic, manny, unable, encroachments, advise, begotten,
# Nearest to from: norouz, loaves, moscow, accompaniment, daltrey, tread, gingerbread, withdrawing,
# Nearest to about: suzaku, genealogy, purse, headlands, herod, kg, irresistible, harryhausen,
# Nearest to at: disappearing, insurance, boondocks, philharmonic, regimental, total, lindh, uniformitarianism,
# Nearest to people: aryana, sunken, majestic, redeeming, freed, declared, smuggler, signatories,
# Nearest to up: breaker, haldeman, spock, celluloid, screw, mango, journalist, depending,
# Nearest to their: rabble, stub, usefully, who, hanover, the, ven, excessive,
# Nearest to into: underemployed, succ, initiative, mecca, humidity, repentant, puppets, kildall,
# Nearest to hit: microcontroller, annul, followed, amarantine, listened, jeane, fg, episode,
# Nearest to older: recording, reconstructing, sari, charenton, female, animators, rime, assessors,
# Nearest to scale: jewellery, reproductive, fatigue, bitrate, filtering, metadata, manganese, agn,
# Nearest to instance: neptunian, canisters, subtle, psychometrics, rendition, milieu, technological, exhibitionism,
# Nearest to joseph: statesman, johan, author, svenska, joannes, johann, d, valens,
# Nearest to centre: lakes, aircrew, ambiente, gains, mircea, rigorously, knapsack, ambon,
# Nearest to engineering: pnc, clothing, pharmaceuticals, containers, internetworking, fermentation, khedive, trough,
# Nearest to consists: nation, slurry, hoop, haldane, recreation, scouting, tectonics, lexicon,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3358 0.6509 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3059 0.5738 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3709 0.5481 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3784 0.5214 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4078 0.4874 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2964 0.5271 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2992 0.5654 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3179 0.6235 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2184 0.5796 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3154 0.6197 sec/batch
# Nearest to been: profile, usury, palaeolithic, begotten, encroachments, whitehead, manny, citizenship,
# Nearest to from: norouz, moscow, loaves, accompaniment, daltrey, summers, frist, gingerbread,
# Nearest to about: suzaku, purse, herod, genealogy, harryhausen, irresistible, softpanorama, marks,
# Nearest to at: disappearing, insurance, philharmonic, boondocks, aeons, cornhuskers, decapitate, valladolid,
# Nearest to people: majestic, sunken, aryana, redeeming, freed, declared, heisei, regress,
# Nearest to up: breaker, haldeman, screw, spock, mango, celluloid, stoney, wall,
# Nearest to their: rabble, stub, usefully, who, hanover, excessive, attempted, halford,
# Nearest to into: succ, underemployed, puppets, humidity, initiative, repentant, mecca, spite,
# Nearest to hit: microcontroller, episode, amarantine, listened, annul, fg, endocarditis, shinji,
# Nearest to older: female, reconstructing, recording, animators, charenton, assessors, rime, pigeonhole,
# Nearest to scale: jewellery, bitrate, reproductive, fatigue, filtering, manganese, straightforward, agn,
# Nearest to instance: neptunian, subtle, canisters, psychometrics, rendition, milieu, mankind, throughput,
# Nearest to joseph: statesman, author, johan, d, joannes, valens, svenska, johann,
# Nearest to centre: lakes, gains, mircea, aircrew, ambiente, knapsack, campus, thuringia,
# Nearest to engineering: pnc, clothing, pharmaceuticals, internetworking, containers, fermentation, khedive, nationalised,
# Nearest to consists: nation, slurry, recreation, haldane, hoop, scouting, tectonics, alloys,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2842 0.5834 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2937 0.5849 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3346 0.2431 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2217 0.5820 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1945 0.6084 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1966 0.6229 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1959 0.6052 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1919 0.6079 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2208 0.6279 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1748 0.5969 sec/batch
# Nearest to been: profile, usury, palaeolithic, manny, unable, dorchester, merdeka, satan,
# Nearest to from: norouz, moscow, loaves, tread, summers, daltrey, ejected, accompaniment,
# Nearest to about: suzaku, limnic, genealogy, irresistible, purse, harryhausen, softpanorama, clay,
# Nearest to at: disappearing, insurance, catastrophic, adel, philharmonic, total, commences, aeons,
# Nearest to people: majestic, redeeming, aryana, sunken, freed, heisei, regress, declared,
# Nearest to up: breaker, haldeman, spock, screw, celluloid, wall, roof, stoney,
# Nearest to their: rabble, stub, usefully, excessive, who, yardage, hanover, having,
# Nearest to into: succ, underemployed, initiative, puppets, humidity, repentant, wideawake, mecca,
# Nearest to hit: microcontroller, episode, fg, listened, amarantine, shinji, career, endocarditis,
# Nearest to older: female, recording, reconstructing, charenton, animators, median, pigeonhole, mcluhan,
# Nearest to scale: bitrate, jewellery, manganese, filtering, reproductive, fatigue, rows, straightforward,
# Nearest to instance: neptunian, subtle, canisters, milieu, psychometrics, mankind, exhibitionism, throughput,
# Nearest to joseph: statesman, johan, author, joannes, valens, d, johann, svenska,
# Nearest to centre: lakes, mall, ambiente, gains, mircea, campus, thuringia, knapsack,
# Nearest to engineering: pnc, pharmaceuticals, clothing, internetworking, containers, nationalised, fermentation, research,
# Nearest to consists: nation, slurry, haldane, recreation, scouting, alloys, hoop, pound,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2353 0.5800 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2351 0.5964 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2257 0.6472 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1180 0.4995 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1392 0.5443 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1575 0.5652 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1451 0.5546 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1353 0.6257 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1754 0.6189 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1460 0.6022 sec/batch
# Nearest to been: profile, usury, palaeolithic, manny, unable, whitehead, prehistoric, radiochemistry,
# Nearest to from: norouz, loaves, moscow, tread, ejected, summers, daltrey, frist,
# Nearest to about: genealogy, suzaku, harryhausen, copper, mountains, irresistible, headlands, bakufu,
# Nearest to at: disappearing, insurance, adel, philharmonic, regimental, total, commences, boondocks,
# Nearest to people: aryana, sunken, redeeming, majestic, heisei, regress, declared, freed,
# Nearest to up: breaker, haldeman, screw, spock, celluloid, wall, stoney, regrouped,
# Nearest to their: rabble, stub, who, usefully, having, excessive, hanover, attempted,
# Nearest to into: succ, initiative, underemployed, puppets, chestnut, humidity, radiometer, wideawake,
# Nearest to hit: microcontroller, slam, career, listened, episode, kindia, amarantine, shinji,
# Nearest to older: female, median, reconstructing, versus, animators, age, charenton, recording,
# Nearest to scale: jewellery, manganese, bitrate, reproductive, filtering, straightforward, tonality, fatigue,
# Nearest to instance: neptunian, throughput, psychometrics, canisters, subtle, mdma, exhibitionism, mankind,
# Nearest to joseph: statesman, johan, author, joannes, cena, valens, svenska, benoit,
# Nearest to centre: lakes, mall, ambiente, gains, knapsack, mircea, aircrew, campus,
# Nearest to engineering: pnc, pharmaceuticals, internetworking, research, clothing, nationalised, khedive, containers,
# Nearest to consists: nation, slurry, scouting, haldane, alloys, recreation, hoop, lexicon,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1394 0.7743 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2157 0.6592 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1632 0.6360 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1340 0.5295 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1515 0.5889 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1757 0.5662 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1885 0.5798 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1219 0.6264 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1075 0.6232 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1738 0.5370 sec/batch
# Nearest to been: profile, usury, manny, palaeolithic, citizenship, unable, dorchester, whitehead,
# Nearest to from: norouz, loaves, moscow, accompaniment, tread, summers, ejected, yueh,
# Nearest to about: harryhausen, genealogy, suzaku, irresistible, reassurance, purse, softpanorama, limnic,
# Nearest to at: philharmonic, disappearing, adel, insurance, follett, boondocks, product, nas,
# Nearest to people: redeeming, aryana, sunken, majestic, freed, heisei, regress, moustache,
# Nearest to up: breaker, haldeman, wall, celluloid, screw, roof, smashed, spock,
# Nearest to their: rabble, who, stub, usefully, ven, having, skits, therus,
# Nearest to into: initiative, succ, underemployed, wideawake, puppets, harmonium, radiometer, chestnut,
# Nearest to hit: microcontroller, billboard, followed, episode, listened, endocarditis, kindia, swim,
# Nearest to older: female, median, age, reconstructing, animators, versus, pigeonhole, early,
# Nearest to scale: manganese, bitrate, jewellery, straightforward, reproductive, whites, tonality, filtering,
# Nearest to instance: neptunian, canisters, subtle, psychometrics, throughput, exhibitionism, mdma, rendition,
# Nearest to joseph: statesman, johan, author, joannes, svenska, valens, johann, d,
# Nearest to centre: lakes, mall, gains, ambiente, mircea, aircrew, campus, knapsack,
# Nearest to engineering: pnc, pharmaceuticals, research, internetworking, nationalised, clothing, khedive, electronics,
# Nearest to consists: nation, slurry, haldane, scouting, hoop, alloys, recreation, lexicon,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1439 0.4806 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1599 18.4470 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1757 2.6302 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1839 0.5696 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.0762 0.5583 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1163 0.4915 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1338 0.4915 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1264 0.4833 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1666 0.4872 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2355 0.4974 sec/batch
# Nearest to been: profile, citizenship, usury, unable, palaeolithic, manny, dorchester, akhenaten,
# Nearest to from: norouz, moscow, frist, loaves, tread, yueh, daltrey, and,
# Nearest to about: irresistible, harryhausen, suzaku, genealogy, hell, purse, softpanorama, virtually,
# Nearest to at: philharmonic, adel, follett, valladolid, ranuccio, insurance, coupe, brueys,
# Nearest to people: redeeming, regress, majestic, vesalius, sunken, heisei, declared, freed,
# Nearest to up: breaker, wall, haldeman, munster, screw, regrouped, celluloid, spock,
# Nearest to their: rabble, who, ven, the, attempted, esdras, having, stub,
# Nearest to into: initiative, puppets, succ, underemployed, wideawake, harmonium, mecca, shanahan,
# Nearest to hit: billboard, slam, listened, followed, microcontroller, daniels, swim, albums,
# Nearest to older: female, median, reconstructing, age, animators, pigeonhole, versus, aspectual,
# Nearest to scale: manganese, bitrate, jewellery, tonality, whites, filtering, straightforward, reproductive,
# Nearest to instance: neptunian, canisters, subtle, psychometrics, milieu, exhibitionism, rendition, beginning,
# Nearest to joseph: author, johan, statesman, joannes, d, cena, valens, svenska,
# Nearest to centre: lakes, gains, mall, ambiente, mircea, aircrew, campus, knapsack,
# Nearest to engineering: pnc, pharmaceuticals, internetworking, research, nationalised, clothing, khedive, electronics,
# Nearest to consists: nation, slurry, haldane, scouting, alloys, hoop, recreation, lexicon,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1827 0.5227 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.0882 0.4802 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0925 0.5176 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1158 0.4895 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0236 0.4902 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1136 0.4968 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1122 0.5071 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0879 0.4862 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1406 0.0568 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1281 0.4805 sec/batch
# Nearest to been: profile, citizenship, palaeolithic, dorchester, unable, usury, manny, akhenaten,
# Nearest to from: norouz, moscow, loaves, summers, severly, and, the, frist,
# Nearest to about: irresistible, harryhausen, hell, suzaku, softpanorama, genealogy, purse, virtually,
# Nearest to at: total, adel, philharmonic, disappearing, insurance, chf, commences, coupe,
# Nearest to people: regress, vesalius, redeeming, majestic, sunken, preference, heisei, aryana,
# Nearest to up: breaker, wall, screw, haldeman, spock, munster, smashed, depending,
# Nearest to their: rabble, stub, who, the, having, harpists, usefully, dislocations,
# Nearest to into: succ, initiative, puppets, wideawake, underemployed, harmonium, kildall, radiometer,
# Nearest to hit: slam, billboard, followed, listened, daniels, kindia, swim, mcenroe,
# Nearest to older: median, female, age, pigeonhole, animators, females, versus, reconstructing,
# Nearest to scale: bitrate, manganese, tonality, straightforward, jewellery, ribosome, filtering, spacing,
# Nearest to instance: neptunian, subtle, psychometrics, canisters, throughput, hypertext, rendition, exhibitionism,
# Nearest to joseph: statesman, johan, author, joannes, cena, benoit, d, svenska,
# Nearest to centre: mall, lakes, gains, mircea, ambiente, campus, construction, edo,
# Nearest to engineering: pnc, pharmaceuticals, internetworking, research, nationalised, clothing, khedive, electronics,
# Nearest to consists: slurry, nation, scouting, haldane, recreation, alloys, lexicon, hoop,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0848 0.5023 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0335 0.4898 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0804 0.5053 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0285 0.4749 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0597 0.4960 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0195 0.4833 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0540 0.4757 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0613 0.4877 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0659 0.5036 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0117 0.4840 sec/batch
# Nearest to been: manny, profile, unable, dorchester, citizenship, palaeolithic, usury, since,
# Nearest to from: norouz, the, moscow, and, loaves, mamluks, croats, tread,
# Nearest to about: mountains, harryhausen, genealogy, giant, sumbawa, virtually, suzaku, irresistible,
# Nearest to at: adel, total, disappearing, down, chf, on, commences, faster,
# Nearest to people: regress, vesalius, redeeming, sunken, aryana, preference, heisei, shawar,
# Nearest to up: breaker, screw, wall, spock, smashed, regrouped, roof, huge,
# Nearest to their: rabble, the, stub, who, having, harpists, ven, attempted,
# Nearest to into: puppets, succ, initiative, wideawake, underemployed, harmonium, clocked, comparably,
# Nearest to hit: slam, mcenroe, followed, billboard, swim, kindia, microcontroller, listened,
# Nearest to older: median, age, female, females, versus, animators, pigeonhole, reconstructing,
# Nearest to scale: bitrate, manganese, tonality, jewellery, straightforward, whites, ribosome, spacing,
# Nearest to instance: neptunian, psychometrics, subtle, canisters, exhibitionism, selflessness, beginning, throughput,
# Nearest to joseph: johan, statesman, author, joannes, benoit, cena, andrews, svenska,
# Nearest to centre: mall, lakes, gains, mircea, ambiente, campus, edo, residential,
# Nearest to engineering: pnc, pharmaceuticals, research, internetworking, nationalised, mediumwave, khedive, lada,
# Nearest to consists: nation, slurry, scouting, haldane, recreation, audiencia, hoop, lexicon,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9832 0.5130 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9922 0.5739 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9736 0.5898 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0060 0.5209 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0145 0.5232 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0238 0.5035 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0048 0.4944 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0788 0.5193 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0522 0.5327 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.9825 0.6463 sec/batch
# Nearest to been: profile, since, citizenship, dorchester, palaeolithic, manny, unable, usury,
# Nearest to from: norouz, and, nucleotide, the, mamluks, loaves, croats, observationally,
# Nearest to about: harryhausen, mountains, genealogy, sumbawa, suzaku, virtually, bakufu, aristarchus,
# Nearest to at: total, arcseconds, chf, adel, philharmonic, disappearing, faster, detector,
# Nearest to people: heisei, regress, preference, vesalius, redeeming, sunken, shawar, moustache,
# Nearest to up: breaker, screw, wall, smashed, spock, depending, mango, celluloid,
# Nearest to their: rabble, who, the, having, stub, aerobic, ven, money,
# Nearest to into: initiative, puppets, succ, clocked, indirectly, underemployed, wideawake, radiometer,
# Nearest to hit: slam, billboard, mcenroe, followed, swim, kindia, rapping, microcontroller,
# Nearest to older: median, age, females, female, versus, reconstructing, households, pigeonhole,
# Nearest to scale: manganese, bitrate, tonality, straightforward, jewellery, whites, ribosome, filtering,
# Nearest to instance: neptunian, psychometrics, subtle, throughput, exhibitionism, canisters, interpreted, mdma,
# Nearest to joseph: johan, statesman, author, andrews, joannes, cena, benoit, schiller,
# Nearest to centre: mall, lakes, gains, ambiente, mircea, campus, gifted, indepth,
# Nearest to engineering: pnc, pharmaceuticals, research, electronics, internetworking, mediumwave, lada, physical,
# Nearest to consists: slurry, nation, scouting, haldane, audiencia, recreation, alloys, lexicon,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0529 0.5437 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0647 0.5318 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0140 0.5715 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0294 0.5102 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0853 0.5185 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 3.9887 0.5320 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0069 0.5369 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0271 0.4936 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0729 0.5114 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0331 0.4900 sec/batch
# Nearest to been: palaeolithic, akhenaten, profile, unable, since, dorchester, citizenship, manny,
# Nearest to from: norouz, the, and, croats, bernicia, mamluks, loaves, taira,
# Nearest to about: genealogy, harryhausen, irresistible, mountains, sumbawa, bakufu, aristarchus, suzaku,
# Nearest to at: adel, philharmonic, chf, arcseconds, total, valladolid, ranuccio, disappearing,
# Nearest to people: redeeming, vesalius, sunken, regress, heisei, preference, moustache, shawar,
# Nearest to up: breaker, smashed, wall, munster, screw, depending, huge, spock,
# Nearest to their: rabble, the, who, having, ven, esdras, opinionated, for,
# Nearest to into: initiative, puppets, wideawake, succ, indirectly, regions, harmonium, chestnut,
# Nearest to hit: followed, mcenroe, billboard, rapping, slam, kindia, swim, microcontroller,
# Nearest to older: median, age, females, female, versus, pigeonhole, reconstructing, aspectual,
# Nearest to scale: manganese, tonality, bitrate, whites, jewellery, straightforward, fatigue, cordilleras,
# Nearest to instance: neptunian, subtle, psychometrics, beginning, canisters, exhibitionism, hypertext, sterilizing,
# Nearest to joseph: johan, andrews, author, statesman, joannes, benoit, wimsey, resolving,
# Nearest to centre: lakes, mall, gains, ambiente, mircea, gifted, campus, edo,
# Nearest to engineering: pnc, pharmaceuticals, research, electronics, internetworking, mediumwave, khedive, lada,
# Nearest to consists: scouting, slurry, nation, audiencia, haldane, recreation, lexicon, hoop,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0348 0.5435 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9528 0.5170 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0150 0.5065 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0664 0.4938 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 3.9862 0.4988 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1041 0.4916 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1024 0.5042 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0264 0.5071 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9756 0.4908 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0121 0.4750 sec/batch
# Nearest to been: since, unable, citizenship, profile, dorchester, merdeka, palaeolithic, usury,
# Nearest to from: norouz, the, and, mamluks, loaves, taira, bernicia, http,
# Nearest to about: genealogy, sumbawa, wyman, harryhausen, bakufu, irresistible, suzaku, descendents,
# Nearest to at: adel, philharmonic, arcseconds, valladolid, chf, total, commences, greystone,
# Nearest to people: vesalius, sunken, redeeming, grossman, heisei, shawar, regress, moustache,
# Nearest to up: breaker, wall, huge, smashed, screw, munster, depending, spock,
# Nearest to their: rabble, who, the, having, fervent, they, ven, therus,
# Nearest to into: initiative, puppets, succ, wideawake, clocked, harmonium, penrose, indirectly,
# Nearest to hit: billboard, mcenroe, followed, rapping, kindia, slam, albums, lasted,
# Nearest to older: median, females, age, female, versus, pigeonhole, animators, households,
# Nearest to scale: tonality, manganese, bitrate, straightforward, whites, jewellery, toku, cellos,
# Nearest to instance: neptunian, subtle, psychometrics, canisters, beginning, throughput, exhibitionism, evaluator,
# Nearest to joseph: johan, author, andrews, schiller, statesman, cena, benoit, joannes,
# Nearest to centre: mall, lakes, gains, mircea, ambiente, gifted, kerenyi, campus,
# Nearest to engineering: pharmaceuticals, pnc, research, electronics, internetworking, mediumwave, lada, khedive,
# Nearest to consists: slurry, scouting, nation, audiencia, haldane, each, hoop, provincias,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9969 0.5395 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9859 0.4918 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0391 0.5305 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0080 0.6153 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0541 0.5856 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0046 0.4405 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9832 0.6200 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9554 0.6410 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9952 0.5850 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9247 0.7117 sec/batch
# Nearest to been: since, unable, dorchester, crowded, profile, akhenaten, merdeka, citizenship,
# Nearest to from: the, norouz, and, mamluks, an, bernicia, loaves, observationally,
# Nearest to about: sumbawa, aristarchus, larch, genealogy, bakufu, mountains, hell, harryhausen,
# Nearest to at: adel, philharmonic, arcseconds, regent, valladolid, first, commences, total,
# Nearest to people: regress, vesalius, heisei, grossman, redeeming, sunken, shawar, preference,
# Nearest to up: breaker, wall, huge, smashed, depending, munster, screw, servlet,
# Nearest to their: rabble, the, who, having, stub, they, carbonates, for,
# Nearest to into: puppets, initiative, wideawake, succ, clocked, harmonium, radiometer, vienna,
# Nearest to hit: billboard, mcenroe, followed, kindia, rapping, slam, albums, charts,
# Nearest to older: median, females, age, versus, households, female, pigeonhole, household,
# Nearest to scale: tonality, manganese, bitrate, straightforward, cellos, spacing, notated, jewellery,
# Nearest to instance: neptunian, subtle, psychometrics, canisters, exhibitionism, beginning, rendition, milieu,
# Nearest to joseph: johan, andrews, author, schiller, statesman, benoit, cena, diarist,
# Nearest to centre: mall, lakes, mircea, gains, residential, campus, ambiente, indepth,
# Nearest to engineering: pharmaceuticals, pnc, research, electronics, mediumwave, internetworking, nationalised, lada,
# Nearest to consists: nation, scouting, slurry, audiencia, haldane, each, hoop, recreation,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9444 0.6663 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.8988 0.5461 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9801 0.7470 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9820 0.4941 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9744 0.5110 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9808 0.5248 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8778 0.5120 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9068 0.5109 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9260 0.5243 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9075 0.5540 sec/batch
# Nearest to been: since, unable, palaeolithic, profile, merdeka, xxviii, manny, crowded,
# Nearest to from: the, and, norouz, mamluks, croats, nucleotide, fertilize, observationally,
# Nearest to about: sumbawa, aristarchus, genealogy, larch, kg, bakufu, giant, limnic,
# Nearest to at: adel, arcseconds, philharmonic, first, total, birth, regent, valladolid,
# Nearest to people: heisei, regress, vesalius, sunken, redeeming, deaths, shawar, preference,
# Nearest to up: breaker, depending, smashed, huge, wall, farnham, screw, just,
# Nearest to their: the, rabble, who, they, having, for, peasantry, ven,
# Nearest to into: initiative, puppets, wideawake, clocked, radiometer, vienna, divisions, keeps,
# Nearest to hit: mcenroe, followed, billboard, kindia, slam, rapping, lasted, strikeouts,
# Nearest to older: median, females, age, versus, household, households, female, householder,
# Nearest to scale: tonality, manganese, straightforward, bitrate, cellos, spacing, toku, jewellery,
# Nearest to instance: neptunian, subtle, psychometrics, evaluator, canisters, exhibitionism, throughput, milieu,
# Nearest to joseph: andrews, johan, schiller, author, statesman, benoit, cena, greeley,
# Nearest to centre: mall, lakes, ambiente, gains, indepth, mircea, gifted, elasticity,
# Nearest to engineering: pharmaceuticals, pnc, research, internetworking, mediumwave, lada, foundations, commissioning,
# Nearest to consists: nation, scouting, slurry, audiencia, each, haldane, provincias, hoop,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9479 0.5821 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9610 0.5680 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9269 0.5579 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9488 0.6436 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9917 0.5189 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9005 0.5304 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9439 0.5830 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9710 0.6192 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9392 0.5440 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9402 0.5287 sec/batch
# Nearest to been: since, profile, crowded, manny, unable, dorchester, merdeka, palaeolithic,
# Nearest to from: the, norouz, and, bernicia, croats, mamluks, observationally, tread,
# Nearest to about: harryhausen, sumbawa, aristarchus, larch, genealogy, bakufu, ebooks, alicante,
# Nearest to at: adel, arcseconds, philharmonic, total, chf, first, valladolid, detector,
# Nearest to people: heisei, vesalius, regress, shawar, moustache, grossman, redeeming, smuggler,
# Nearest to up: breaker, huge, depending, smashed, wall, just, farnham, munster,
# Nearest to their: rabble, the, who, they, having, ven, peasantry, esdras,
# Nearest to into: initiative, puppets, wideawake, divisions, indirectly, keeps, succ, clocked,
# Nearest to hit: mcenroe, followed, billboard, kindia, rapping, lasted, slam, strikeouts,
# Nearest to older: median, females, age, versus, household, households, female, householder,
# Nearest to scale: tonality, manganese, straightforward, bitrate, methylation, cellos, jewellery, fatigue,
# Nearest to instance: neptunian, subtle, psychometrics, canisters, exhibitionism, throughput, evaluator, selflessness,
# Nearest to joseph: johan, andrews, author, greeley, statesman, laramie, schiller, cena,
# Nearest to centre: mall, lakes, ambiente, gains, indepth, gifted, kerenyi, mircea,
# Nearest to engineering: pnc, pharmaceuticals, internetworking, electronics, research, mediumwave, lada, physical,
# Nearest to consists: scouting, nation, slurry, each, audiencia, haldane, hoop, provincias,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9930 0.5736 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9379 0.5600 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9440 0.5672 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9722 0.6171 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9822 0.5560 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0059 0.5183 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9481 0.6047 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9373 0.6047 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9114 0.5750 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9960 0.6219 sec/batch
# Nearest to been: since, profile, unable, crowded, palaeolithic, monoxide, merdeka, akhenaten,
# Nearest to from: the, and, norouz, bernicia, croats, mamluks, an, to,
# Nearest to about: genealogy, sumbawa, aristarchus, harryhausen, bakufu, irresistible, larch, limnic,
# Nearest to at: adel, philharmonic, arcseconds, total, valladolid, chf, first, regent,
# Nearest to people: vesalius, grossman, deaths, shawar, regress, heisei, sunken, smuggler,
# Nearest to up: breaker, huge, wall, munster, depending, smashed, exponential, thefts,
# ...
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 3.8154 0.5325 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 3.8847 0.5715 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 3.8715 0.5519 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 3.7971 0.5217 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 3.8776 0.5345 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 3.8887 0.5496 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 3.8982 0.5442 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 3.8752 0.5528 sec/batch
# Nearest to been: since, unable, profile, uninhibited, anderson, crowded, monoxide, xt,
# Nearest to from: the, and, an, norouz, observationally, a, of, bernicia,
# Nearest to about: sumbawa, aristarchus, genealogy, harryhausen, decompose, houser, ebooks, tennessee,
# Nearest to at: arcseconds, adel, first, this, total, philharmonic, faster, sinners,
# Nearest to people: deaths, cholinesterase, regress, grossman, vesalius, declared, heisei, smuggler,
# Nearest to up: breaker, depending, huge, smashed, farnham, just, them, wall,
# Nearest to their: they, the, who, rabble, having, for, since, flicker,
# Nearest to into: puppets, divisions, initiative, indirectly, keeps, harmonium, photosynthetic, clocked,
# Nearest to hit: mcenroe, billboard, hits, kindia, strikeouts, followed, rapping, lasted,
# Nearest to older: females, median, age, versus, household, households, five, female,
# Nearest to scale: tonality, manganese, straightforward, fatigue, cellos, jewellery, billion, nitrocellulose,
# Nearest to instance: neptunian, evaluator, subtle, selflessness, rendition, psychometrics, throughput, licentious,
# Nearest to joseph: andrews, benoit, johan, kendrew, greeley, schiller, girondins, resolving,
# Nearest to centre: ambiente, indepth, mall, kerenyi, lakes, elasticity, gains, gifted,
# Nearest to engineering: pharmaceuticals, pnc, physical, lada, research, mediumwave, commissioning, internetworking,
# Nearest to consists: each, scouting, nation, audiencia, slurry, provincias, superchargers, governs,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 3.9400 0.6127 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 3.8865 0.5275 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 3.8760 0.4747 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 3.8543 0.4784 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 3.8826 0.5203 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 3.9589 0.5361 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 3.8789 0.5701 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 3.8652 0.5934 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 3.9051 0.5727 sec/batch
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 3.9215 0.5474 sec/batch
# Nearest to been: since, profile, unable, crowded, anderson, uninhibited, merdeka, palaeolithic,
# Nearest to from: the, and, norouz, an, bernicia, observationally, of, a,
# Nearest to about: sumbawa, aristarchus, genealogy, harryhausen, ebooks, wyman, decompose, one,
# Nearest to at: philharmonic, arcseconds, adel, total, sinners, this, first, births,
# Nearest to people: grossman, vesalius, deaths, entertainers, cholinesterase, smuggler, why, regress,
# Nearest to up: breaker, depending, huge, munster, wall, just, smashed, decentralisation,
# Nearest to their: they, the, who, rabble, having, for, since, playford,
# Nearest to into: initiative, divisions, puppets, shanahan, photosynthetic, harmonium, indirectly, wideawake,
# Nearest to hit: mcenroe, billboard, rapping, followed, hits, kindia, strikeouts, lasted,
# Nearest to older: females, median, age, versus, household, households, pigeonhole, householder,
# Nearest to scale: tonality, manganese, straightforward, nitrocellulose, cellos, fatigue, whites, billion,
# Nearest to instance: evaluator, neptunian, subtle, rendition, psychometrics, selflessness, interpreted, canisters,
# Nearest to joseph: andrews, johan, greeley, benoit, kendrew, author, ciar, girondins,
# Nearest to centre: ambiente, indepth, mall, kerenyi, hertfordshire, lakes, centres, gains,
# Nearest to engineering: pharmaceuticals, pnc, physical, lada, electronics, mediumwave, commissioning, research,
# Nearest to consists: scouting, each, nation, audiencia, provincias, slurry, superchargers, governs,
# Epoch 6/10 Iteration: 26100 Avg. Training loss: 3.9226 0.5495 sec/batch
# Epoch 6/10 Iteration: 26200 Avg. Training loss: 3.9026 0.6351 sec/batch
# Epoch 6/10 Iteration: 26300 Avg. Training loss: 3.9048 0.5916 sec/batch
# Epoch 6/10 Iteration: 26400 Avg. Training loss: 3.9033 0.4874 sec/batch
# Epoch 6/10 Iteration: 26500 Avg. Training loss: 3.8581 0.5288 sec/batch
# Epoch 6/10 Iteration: 26600 Avg. Training loss: 3.9162 0.5302 sec/batch
# Epoch 6/10 Iteration: 26700 Avg. Training loss: 3.8689 0.4857 sec/batch
# Epoch 6/10 Iteration: 26800 Avg. Training loss: 3.9858 0.4912 sec/batch
# Epoch 6/10 Iteration: 26900 Avg. Training loss: 3.9837 0.7018 sec/batch
# Epoch 6/10 Iteration: 27000 Avg. Training loss: 3.9645 0.6277 sec/batch
# Nearest to been: since, unable, profile, akhenaten, merdeka, crowded, palaeolithic, xxviii,
# Nearest to from: the, and, norouz, an, in, of, to, bernicia,
# Nearest to about: sumbawa, aristarchus, genealogy, bakufu, wyman, ebooks, descendents, irresistible,
# Nearest to at: philharmonic, adel, arcseconds, first, valladolid, total, ranuccio, regent,
# Nearest to people: deaths, grossman, entertainers, vesalius, living, shawar, residents, smuggler,
# Nearest to up: breaker, huge, wall, munster, depending, smashed, decentralisation, them,
# Nearest to their: they, the, who, rabble, having, for, ven, playford,
# Nearest to into: puppets, divisions, initiative, harmonium, shanahan, pashtuns, penrose, yavapai,
# Nearest to hit: mcenroe, billboard, kindia, rapping, followed, hits, charts, lasted,
# Nearest to older: median, females, age, versus, household, households, pigeonhole, householder,
# Nearest to scale: tonality, manganese, fatigue, fy, nitrocellulose, toku, whites, straightforward,
# Nearest to instance: neptunian, subtle, rendition, psychometrics, selflessness, evaluator, canisters, phallic,
# Nearest to joseph: andrews, author, benoit, kendrew, greeley, christ, johan, schiller,
# Nearest to centre: ambiente, indepth, gifted, gains, lakes, mall, kerenyi, hertfordshire,
# Nearest to engineering: pharmaceuticals, pnc, physical, lada, electronics, commissioning, mediumwave, exopterygota,
# Nearest to consists: scouting, each, audiencia, provincias, slurry, nation, superchargers, rensselaer,
# Epoch 6/10 Iteration: 27100 Avg. Training loss: 3.8855 0.6260 sec/batch
# Epoch 6/10 Iteration: 27200 Avg. Training loss: 3.8595 0.5573 sec/batch
# Epoch 6/10 Iteration: 27300 Avg. Training loss: 3.8694 0.5679 sec/batch
# Epoch 6/10 Iteration: 27400 Avg. Training loss: 3.7853 0.5293 sec/batch
# Epoch 6/10 Iteration: 27500 Avg. Training loss: 3.9375 0.4983 sec/batch
# Epoch 6/10 Iteration: 27600 Avg. Training loss: 3.9087 0.5741 sec/batch
# Epoch 6/10 Iteration: 27700 Avg. Training loss: 3.8861 0.6263 sec/batch
# Epoch 7/10 Iteration: 27800 Avg. Training loss: 3.9403 0.1299 sec/batch
# Epoch 7/10 Iteration: 27900 Avg. Training loss: 3.8744 0.5227 sec/batch
# Epoch 7/10 Iteration: 28000 Avg. Training loss: 3.8692 0.5666 sec/batch
# Nearest to been: since, unable, xxviii, profile, merdeka, palaeolithic, akhenaten, monoxide,
# Nearest to from: the, and, an, of, in, a, to, norouz,
# Nearest to about: aristarchus, sumbawa, genealogy, externalization, decompose, irresistible, ebooks, bakufu,
# Nearest to at: arcseconds, total, adel, first, philharmonic, romantically, detector, birth,
# Nearest to people: deaths, grossman, entertainers, vesalius, living, residents, shawar, regress,
# Nearest to up: huge, depending, breaker, wall, munster, decentralisation, just, smashed,
# Nearest to their: they, the, who, rabble, having, since, flicker, nix,
# Nearest to into: puppets, divisions, harmonium, shanahan, penrose, initiative, headmaster, s,
# Nearest to hit: mcenroe, billboard, kindia, charts, rapping, hits, followed, lasted,
# Nearest to older: females, median, age, versus, household, households, householder, pigeonhole,
# Nearest to scale: tonality, manganese, scales, cellos, bore, fatigue, straightforward, nitrocellulose,
# Nearest to instance: neptunian, canisters, subtle, psychometrics, evaluator, milieu, selflessness, throughput,
# Nearest to joseph: andrews, benoit, kendrew, author, johan, greeley, christ, schiller,
# Nearest to centre: ambiente, indepth, mall, centres, lakes, hertfordshire, kerenyi, gains,
# Nearest to engineering: pharmaceuticals, pnc, physical, lada, commissioning, electronics, mediumwave, accelerate,
# Nearest to consists: scouting, each, provincias, audiencia, nation, governs, rensselaer, slurry,
# Epoch 7/10 Iteration: 28100 Avg. Training loss: 3.8587 0.6063 sec/batch
# Epoch 7/10 Iteration: 28200 Avg. Training loss: 3.8605 0.6198 sec/batch
# Epoch 7/10 Iteration: 28300 Avg. Training loss: 3.8259 0.7162 sec/batch
# Epoch 7/10 Iteration: 28400 Avg. Training loss: 3.8758 0.6231 sec/batch
# Epoch 7/10 Iteration: 28500 Avg. Training loss: 3.8172 0.5542 sec/batch
# Epoch 7/10 Iteration: 28600 Avg. Training loss: 3.8504 0.6701 sec/batch
# Epoch 7/10 Iteration: 28700 Avg. Training loss: 3.8712 0.6601 sec/batch
# Epoch 7/10 Iteration: 28800 Avg. Training loss: 3.9010 0.6804 sec/batch
# Epoch 7/10 Iteration: 28900 Avg. Training loss: 3.7856 0.6273 sec/batch
# Epoch 7/10 Iteration: 29000 Avg. Training loss: 3.7928 0.6063 sec/batch
# Nearest to been: since, profile, unable, crowded, merdeka, xxviii, palaeolithic, akhenaten,
# Nearest to from: the, and, an, of, in, to, a, most,
# Nearest to about: sumbawa, aristarchus, genealogy, one, bakufu, limnic, hydropower, zero,
# Nearest to at: total, arcseconds, adel, on, four, first, births, this,
# Nearest to people: deaths, grossman, godavari, entertainers, shawar, chuvash, why, vesalius,
# Nearest to up: depending, huge, wall, munster, breaker, smashed, just, them,
# Nearest to their: they, the, who, rabble, having, most, since, were,
# Nearest to into: divisions, puppets, initiative, pashtuns, indirectly, struma, yavapai, photosynthetic,
# Nearest to hit: mcenroe, billboard, kindia, strikeouts, hits, lasted, charts, followed,
# Nearest to older: females, median, age, versus, household, householder, households, pigeonhole,
# Nearest to scale: tonality, manganese, fatigue, scales, nitrocellulose, fy, straightforward, rationing,
# Nearest to instance: neptunian, psychometrics, licentious, evaluator, rendition, subtle, selflessness, billiards,
# Nearest to joseph: andrews, kendrew, benoit, greeley, johan, christ, schiller, author,
# Nearest to centre: mall, ambiente, indepth, centres, lakes, structures, gains, kerenyi,
# Nearest to engineering: pharmaceuticals, pnc, physical, lada, commissioning, engineers, nationalised, mediumwave,
# Nearest to consists: scouting, each, audiencia, nation, provincias, governs, rensselaer, bodleian,
# Epoch 7/10 Iteration: 29100 Avg. Training loss: 3.8187 0.6340 sec/batch
# Epoch 7/10 Iteration: 29200 Avg. Training loss: 3.7614 0.6797 sec/batch
# Epoch 7/10 Iteration: 29300 Avg. Training loss: 3.8380 0.6135 sec/batch
# Epoch 7/10 Iteration: 29400 Avg. Training loss: 3.8663 0.5408 sec/batch
# Epoch 7/10 Iteration: 29500 Avg. Training loss: 3.8427 0.5521 sec/batch
# Epoch 7/10 Iteration: 29600 Avg. Training loss: 3.8669 0.5644 sec/batch
# Epoch 7/10 Iteration: 29700 Avg. Training loss: 3.8920 0.6539 sec/batch
# Epoch 7/10 Iteration: 29800 Avg. Training loss: 3.8786 0.8049 sec/batch
# Epoch 7/10 Iteration: 29900 Avg. Training loss: 3.8505 0.5259 sec/batch
# Epoch 7/10 Iteration: 30000 Avg. Training loss: 3.8325 0.4972 sec/batch
# Nearest to been: since, profile, crowded, unable, uninhibited, anderson, palaeolithic, has,
# Nearest to from: the, and, of, an, in, a, observationally, to,
# Nearest to about: sumbawa, aristarchus, genealogy, ebooks, one, irresistible, bakufu, harryhausen,
# Nearest to at: total, arcseconds, first, this, adel, four, sinners, on,
# Nearest to people: deaths, grossman, shawar, entertainers, living, godavari, vesalius, chuvash,
# Nearest to up: breaker, huge, depending, wall, just, smashed, decentralisation, munster,
# Nearest to their: they, who, the, having, rabble, of, most, those,
# Nearest to into: puppets, divisions, through, initiative, indirectly, shanahan, keeps, pashtuns,
# Nearest to hit: mcenroe, billboard, kindia, hits, lasted, charts, listened, rapping,
# Nearest to older: females, median, age, versus, household, households, householder, five,
# Nearest to scale: tonality, manganese, scales, nitrocellulose, fatigue, earthquake, straightforward, fy,
# Nearest to instance: subtle, evaluator, psychometrics, rendition, canisters, neptunian, billiards, licentious,
# Nearest to joseph: andrews, christ, benoit, greeley, kendrew, schiller, jesus, resolving,
# Nearest to centre: indepth, ambiente, mall, kerenyi, lakes, gifted, insertafter, gains,
# Nearest to engineering: pharmaceuticals, pnc, physical, electronics, lada, engineers, commissioning, mediumwave,
# Nearest to consists: scouting, each, nation, audiencia, provincias, governs, leucine, bodleian,
# Epoch 7/10 Iteration: 30100 Avg. Training loss: 3.8705 0.5227 sec/batch
# Epoch 7/10 Iteration: 30200 Avg. Training loss: 3.8507 0.7254 sec/batch
# Epoch 7/10 Iteration: 30300 Avg. Training loss: 3.8688 0.5566 sec/batch
# Epoch 7/10 Iteration: 30400 Avg. Training loss: 3.8755 0.5326 sec/batch
# Epoch 7/10 Iteration: 30500 Avg. Training loss: 3.8692 0.9994 sec/batch
# Epoch 7/10 Iteration: 30600 Avg. Training loss: 3.8629 0.6271 sec/batch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-b1d3869cd0d6> in <module>()
#      18             feed = {inputs: x,
#      19                     labels: np.array(y)[:, None]}
# ---> 20             train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
#      21
#      22             loss += train_loss
#
# /Users/coupang/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/coupang/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /Users/coupang/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/coupang/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /Users/coupang/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
